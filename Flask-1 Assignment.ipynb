# %% [markdown]
# Q.1 - What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro web framework written in Python. It is classified as a microframework because it does not require particular tools or libraries. It has no database abstraction layer, form validation, or any other components where pre-existing third-party libraries provide common functions.

# %% [markdown]
# Advantages of Flask-
#
#
# 1. It is a lightweight framework that offers hassle-free development.
# 2. Provide flexibility to the developer to experiment with their modules or architecture.
# 3. It is suitable for small projects.
# 4. Offers a built-in development server and fast debugger.
# 5. Easily scalable for the applications.
# 6. Support for secure cookies.

# %% [markdown]
# Q.2 - Create a simple Flask application to display ‘Hello World!!’.

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!</h1>"
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot 2023-07-16 110959.png](attachment:4f86f814-1640-4d38-b049-af234cdfc539.png)

# %% [markdown]
# Q.3 - What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is the technique used to map the specific URL with the associated function intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs. It is helpful to access the desired page directly without navigating from the home page.

# %% [markdown]
# Q.4 - Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
#
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/welcome")
# def Welcome():
#     a = { 'Company Name' : 'ABC Corporation' ,
#             'Location' : 'India' ,
#             'Contact Details' : '999-999-9999'
#     }
#     return "Welcome to ABC Corporation{}".format(a)
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot 2023-07-16 123437.png](attachment:1bd6b4f5-af04-458c-a409-750f97b1d076.png)

# %% [markdown]
# Q.5 - What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically.

# %% [markdown]
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/test")
# def URL():
#     data = request.args.get('x')
#     return "This is python code for url building{}".format(data)
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
